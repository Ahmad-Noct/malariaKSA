# %% [markdown]
# ## Preparing python

# %%
import pandas as pd , numpy as np , seaborn as sns

# %% [markdown]
# ### Reading main dataframe

# %%
df18 = pd.read_excel('D:\projects\malaria\malariaKSA\data\malariadata.xlsx',
                       sheet_name= 0 , header=6 , index_col=1, 
                     skipfooter= 2 )
df19 = pd.read_excel('D:\projects\malaria\malariaKSA\data\malariadata.xlsx',
                       sheet_name= 1 , header=5 , index_col=1, 
                    skipfooter= 2)
df20 = pd.read_excel('D:\projects\malaria\malariaKSA\data\malariadata.xlsx',
                       sheet_name= 2 , header=5 , index_col=1, 
                    skipfooter= 2)
df21 = pd.read_excel('D:\projects\malaria\malariaKSA\data\malariadata.xlsx',
                       sheet_name= 3 , header=5 , index_col=1, 
                    skipfooter= 2)
df22 = pd.read_excel('D:\projects\malaria\malariaKSA\data\malariadata.xlsx',
                       sheet_name= 4 , header=5 , index_col=1, 
                    skipfooter= 2)
dfttl = pd.read_excel('D:\projects\malaria\malariaKSA\data\malariadata.xlsx',
                       sheet_name= 5 , header=5 , index_col=1)

# %%
df18 = df18.drop(['Unnamed: 0'], axis=1)
df18 = df18.rename(columns= {'Unnamed: 2':'No.Tested', 'Unnamed: 3' : 'Pos Cases',
                      'Unnamed: 4': 'malignant' , 'Unnamed: 5': 'Non-malignant',
                      'Unnamed: 6': 'Plasmodium','Unnamed: 7':'Quartan',
                      'Unnamed: 8' : 'Double Tertian', 'Unnamed: 9': 'local'
                      ,'Unnamed: 10': 'Alien' , 'Unnamed: 11': 'Non-catagorized'
                      , 'Unnamed: 12' : 'Else'})

# %%
df19 = df19.drop(['Unnamed: 0'], axis=1)
df19 = df19.rename(columns= {'Unnamed: 2':'No.Tested', 'Unnamed: 3' : 'Pos Cases',
                      'Unnamed: 4': 'malignant' , 'Unnamed: 5': 'Non-malignant',
                      'Unnamed: 6': 'Plasmodium','Unnamed: 7':'Quartan',
                      'Unnamed: 8' : 'Double Tertian', 'Unnamed: 9': 'local'
                      ,'Unnamed: 10': 'Alien' , 'Unnamed: 11': 'Non-catagorized'
                      , 'Unnamed: 12' : 'Else'})

# %%
df20 = df20.drop(['Unnamed: 0'], axis=1)
df20 = df20.rename(columns= {'Unnamed: 2':'No.Tested', 'Unnamed: 3' : 'Pos Cases',
                      'Unnamed: 4': 'malignant' , 'Unnamed: 5': 'Non-malignant',
                      'Unnamed: 6': 'Plasmodium','Unnamed: 7':'Quartan',
                      'Unnamed: 8' : 'Double Tertian', 'Unnamed: 9': 'local'
                      ,'Unnamed: 10': 'Alien' , 'Unnamed: 11': 'Non-catagorized'
                      , 'Unnamed: 12' : 'Else'})

# %%
df21 = df21.drop(['Unnamed: 0'], axis=1)
df21 = df21.rename(columns= {'Unnamed: 2':'No.Tested', 'Unnamed: 3' : 'Pos Cases',
                      'Unnamed: 4': 'malignant' , 'Unnamed: 5': 'Non-malignant',
                      'Unnamed: 6': 'Plasmodium','Unnamed: 7':'Quartan',
                      'Unnamed: 8' : 'Double Tertian', 'Unnamed: 9': 'local'
                      ,'Unnamed: 10': 'Introduced' , 'Unnamed: 11': 'Alien'
                      , 'Unnamed: 12' : 'Non-catagorized', 'Unnamed: 13' : 'regressive' })

# %%
df22 = df22.drop(['Unnamed: 0'], axis=1)
df22 = df22.rename(columns= {'Unnamed: 2':'No.Tested', 'Unnamed: 3' : 'Pos Cases',
                      'Unnamed: 4': 'malignant' , 'Unnamed: 5': 'Non-malignant',
                      'Unnamed: 6': 'Plasmodium','Unnamed: 7':'Quartan',
                      'Unnamed: 8' : 'Double Tertian', 'Unnamed: 9': 'local'
                      ,'Unnamed: 10': 'Introduced' , 'Unnamed: 11': 'Alien'
                      , 'Unnamed: 12' : 'Non-catagorized', 'Unnamed: 13' : 'regressive' })

# %%
dfttl = dfttl.drop(['Unnamed: 0'], axis=1)
dfttl= dfttl.rename(columns= {'Unnamed: 2':'No.Tested', 'Unnamed: 3' : 'Pos Cases',
                      'Unnamed: 4': 'malignant' , 'Unnamed: 5': 'Non-malignant',
                      'Unnamed: 6': 'Plasmodium','Unnamed: 7':'Quartan',
                      'Unnamed: 8' : 'Double Tertian', 'Unnamed: 9': 'local'
                      ,'Unnamed: 10': 'Introduced' , 'Unnamed: 11': 'Alien'
                      , 'Unnamed: 12' : 'Non-catagorized', 'Unnamed: 13' : 'regressive' })

# %%
df22
# Out:
#                  No.Tested  Pos Cases  malignant  Non-malignant  Plasmodium  \
# الدمام              191182        270       0.10            139         130
# الأحساء              29656         38       0.10             25          12
# الجوف                43579          7       0.01              0           7
# الحدود الشماليه         78          5       6.40              5           0
# القريات               3446          0       0.00              0           0
# حفر الباطن             189         14       7.40              8           6
# القصيم               68911         72       0.10             21          50
# الرياض               20324        172       0.80             86          80
# بيشة                  1235         16       1.20              8           8
# نجران                26477         50       0.20             21          29
# تبوك                  5535         11       0.20             11           0
# حائل                  3042         18       0.60              7          11
# المدينة المنورة      51094        135       0.30            101          24
# الطائف               85748         93       0.10             38          54
# مكة المكرمة          30930        112       0.40             78          32
# جدة                   3625        410       7.40            170         214
# الليث                 1889          0       0.00              0           0
# القنفذة               2283         11       0.50              7           4
# الباحة                7579         11       0.10              5           6
# جازان               171098       2774       1.60           2284         475
# عسير                 16922        100       0.50             65          35
# المجموع             764822       4319       0.60           3079        1177
#
#                  Quartan  Double Tertian  local  Introduced  Alien  \
# الدمام                 1               0      0           0      0
# الأحساء                1               0      0           0      0
# الجوف                  0               0      0           0      0
# الحدود الشماليه        0               0      0           0      0
# القريات                0               0      0           0      0
# حفر الباطن             0               0      0           0      0
# القصيم                 1               0      0           0      0
# الرياض                 3               3      0           0      0
# بيشة                   0               0      0           0      0
# نجران                  0               0      0           0      0
# تبوك                   0               0      0           0      0
# حائل                   0               0      0           0      0
# المدينة المنورة        0              10      0           0      0
# الطائف                 1               0      0           0      0
# مكة المكرمة            1               1      0           0      0
# جدة                    9              17      0           0      0
# الليث                  0               0      0           0      0
# القنفذة                0               0      0           0      0
# الباحة                 0               0      0           0      0
# جازان                  5               8      2           0    260
# عسير                   0               0      0           0     14
# المجموع               22              39      2           0    274
#
#                  Non-catagorized  regressive  Unnamed: 14
# الدمام                       270           0            0
# الأحساء                       38           0            0
# الجوف                          7           0            0
# الحدود الشماليه                5           0            0
# القريات                        0           0            0
# حفر الباطن                    14           0            0
# القصيم                        72           0            0
# الرياض                       172           0            0
# بيشة                          16           0            0
# نجران                         50           0            0
# تبوك                          11           0            0
# حائل                          18           0            0
# المدينة المنورة              135           0            0
# الطائف                        93           0            0
# مكة المكرمة                  112           0            0
# جدة                          410           0            0
# الليث                          0           0            0
# القنفذة                       11           0            0
# الباحة                        11           0            0
# جازان                       2514           0            0
# عسير                          86           0            0
# المجموع                     4045           0            0
