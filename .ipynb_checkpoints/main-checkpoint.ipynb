# %% [markdown]
# ## Preparing python

# %%
import pandas as pd , numpy as np 
import matplotlib.pyplot as plt
from matplotlib import rc, pyplot as plt

# %% [markdown]
# ### Reading main dataframe

# %%
df18 = pd.read_excel('D:\projects\malaria\malariaKSA\data\malariadata.xlsx',
                       sheet_name= 0 , header=5 , index_col=1, 
                     skipfooter= 2 )

# %%
df19 = pd.read_excel('D:\projects\malaria\malariaKSA\data\malariadata.xlsx',
                       sheet_name= 1 , header=5 , index_col=1, 
                    skipfooter= 2)

# %%
df20 = pd.read_excel('D:\projects\malaria\malariaKSA\data\malariadata.xlsx',
                       sheet_name= 2 , header=6 , index_col=1, 
                    skipfooter= 2)

# %%
df21 = pd.read_excel('D:\projects\malaria\malariaKSA\data\malariadata.xlsx',
                       sheet_name= 3 , header=5 , index_col=1, 
                    skipfooter= 2)

# %%
df22 = pd.read_excel('D:\projects\malaria\malariaKSA\data\malariadata.xlsx',
                       sheet_name= 4 , header=5 , index_col=1, 
                    skipfooter= 2)

# %%
dfttl = pd.read_excel('D:\projects\malaria\malariaKSA\data\malariadata.xlsx',
                       sheet_name= 5 , header=5 , index_col=1)

# %% [markdown]
# # Cleaning data

# %% [markdown]
# ## Year 2018

# %%
df18 = df18.drop(df18.index[0], axis=0)
df18 = df18.drop(['Unnamed: 0'], axis = 1)

# %%
df18 = df18.rename(columns= {'Unnamed: 2':'No.Tested', 'Unnamed: 3' : 'Pos Casses',
                      'خبيثة': 'malignant' , 'حميدة': 'Non-malignant',
                      'بيضاوية': 'Plasmodium','رباعية':'Quartan',
                      'مزدوجة' : 'Double Tertian', 'محلية': 'local'
                      ,'من الخارج': 'Alien' , 'غير مصنفة': 'Non-catagorized'
                      , 'أخرى' : 'Else'})
index = ('Dammam', 'Al-ahssa', 'Al-jowf', 
         'Northern-Borders', 'Qurayat', 
         'hafar-albatin', 'Qaseem', 'Riyadh',
         'Bishaa', 'Najraan', 'Tabook', 'Hail',
         'Madena', 'Taif', 'Mecca', 'Jeddah', 
         'Allaith', 'Alqunfthah', 'Bahaa', 'Jazaan',
         'Aseer', 'Total')

# ---------------------------------------

index = ('Dammam', 'Al-ahssa', 'Al-jowf', 
         'Northern-Borders', 'Qurayat', 
         'hafar-albatin', 'Qaseem', 'Riyadh',
         'Bishaa', 'Najraan', 'Tabook', 'Hail',
         'Madena', 'Taif', 'Mecca', 'Jeddah', 
         'Allaith', 'Alqunfthah', 'Bahaa', 'Jazaan',
         'Aseer', 'Total')

df18diff = df18['No.Tested'] - df18['Pos Casses']
df18.insert(loc = 2,
          column = 'Neg Casses',
          value = df18diff)

df18per = df18['Pos Casses'] / df18['No.Tested'] *100
df18.insert(loc = 3, 
            column = '% of Pos',
            value = df18per)

         
df18 = df18.set_index(pd.Index(index))
         

df18.to_csv("cleaned/2018.csv")

# %% [markdown]
# ## Year 2019

# %%
df19 = df19.drop(['Unnamed: 0'], axis=1)
df19 = df19.rename(columns= {'Unnamed: 2':'No.Tested', 'Unnamed: 3' : 'Pos Casses',
                      'Unnamed: 4': 'malignant' , 'Unnamed: 5': 'Non-malignant',
                      'Unnamed: 6': 'Plasmodium','Unnamed: 7':'Quartan',
                      'Unnamed: 8' : 'Double Tertian', 'Unnamed: 9': 'local'
                      ,'Unnamed: 10': 'Alien' , 'Unnamed: 11': 'Non-catagorized'
                      , 'Unnamed: 12' : 'Else'})

# ---------------------------------------

index = ('Dammam', 'Al-ahssa', 'Al-jowf', 
         'Northern-Borders', 'Qurayat', 
         'hafar-albatin', 'Qaseem', 'Riyadh',
         'Bishaa', 'Najraan', 'Tabook', 'Hail',
         'Madena', 'Taif', 'Mecca', 'Jeddah', 
         'Allaith', 'Alqunfthah', 'Bahaa', 'Jazaan',
         'Aseer', 'Total')

df19diff = df19['No.Tested'] - df19['Pos Casses']
df19.insert(loc = 2,
          column = 'Neg Casses',
          value = df19diff)

df19per = df19['Pos Casses'] / df19['No.Tested'] *100
df19.insert(loc = 3, 
            column = '% of Pos',
            value = df19per)

         
df19 = df19.set_index(pd.Index(index))
         


df19.to_csv("cleaned/2019.csv")

# %% [markdown]
# ## Year 2020

# %%
df20 = df20.drop(['Unnamed: 0'], axis=1)
df20 = df20.rename(columns= {'Unnamed: 2':'No.Tested', 'Unnamed: 3' : 'Pos Casses',
                      'Unnamed: 4': 'malignant' , 'Unnamed: 5': 'Non-malignant',
                      'Unnamed: 6': 'Quartan','Unnamed: 7':'Double Tertian',
                      'Unnamed: 8' : 'local', 'Unnamed: 9': 'Introduced'
                      ,'Unnamed: 10': 'Alien' , 'Unnamed: 11': 'Non-catagorized'
                      , 'Unnamed: 12' : 'Else'})

# ---------------------------------------

index = ('Dammam', 'Al-ahssa', 'Al-jowf', 
         'Northern-Borders', 'Qurayat', 
         'hafar-albatin', 'Qaseem', 'Riyadh',
         'Bishaa', 'Najraan', 'Tabook', 'Hail',
         'Madena', 'Taif', 'Mecca', 'Jeddah', 
         'Allaith', 'Alqunfthah', 'Bahaa', 'Jazaan',
         'Aseer', 'Total')

df20diff = df20['No.Tested'] - df20['Pos Casses']
df20.insert(loc = 2,
          column = 'Neg Casses',
          value = df20diff)

df20per = df20['Pos Casses'] / df20['No.Tested'] *100
df20.insert(loc = 3, 
            column = '% of Pos',
            value = df20per)

         
df20 = df20.set_index(pd.Index(index))
         


df20.to_csv("cleaned/2020.csv")

# %% [markdown]
# ## Year 2021

# %%
df21 = df21.drop(['Unnamed: 0'], axis=1)
df21 = df21.rename(columns= {'Unnamed: 2':'No.Tested', 'Unnamed: 3' : 'Pos Casses',
                      'Unnamed: 4': 'malignant' , 'Unnamed: 5': 'Non-malignant',
                      'Unnamed: 6': 'Plasmodium','Unnamed: 7':'Quartan',
                      'Unnamed: 8' : 'Double Tertian', 'Unnamed: 9': 'local'
                      ,'Unnamed: 10': 'Introduced' , 'Unnamed: 11': 'Alien'
                      , 'Unnamed: 12' : 'Non-catagorized', 'Unnamed: 13' : 'regressive' })

# ---------------------------------------

index = ('Dammam', 'Al-ahssa', 'Al-jowf', 
         'Northern-Borders', 'Qurayat', 
         'hafar-albatin', 'Qaseem', 'Riyadh',
         'Bishaa', 'Najraan', 'Tabook', 'Hail',
         'Madena', 'Taif', 'Mecca', 'Jeddah', 
         'Allaith', 'Alqunfthah', 'Bahaa', 'Jazaan',
         'Aseer', 'Total')

df21diff = df21['No.Tested'] - df21['Pos Casses']
df21.insert(loc = 2,
          column = 'Neg Casses',
          value = df21diff)

df21per = df21['Pos Casses'] / df21['No.Tested'] *100
df21.insert(loc = 3, 
            column = '% of Pos',
            value = df21per)

df21 = df21.set_index(pd.Index(index))

df21.to_csv("cleaned/2021.csv")

# %% [markdown]
# ## Year 2022

# %%
df22 = df22.drop(['Unnamed: 0'], axis=1)
df22 = df22.rename(columns= {'Unnamed: 2':'No.Tested','Unnamed: 3':'Pos Casses', 'Unnamed: 4' : '% of Pos',
                      'Unnamed: 5': 'malignant' , 'Unnamed: 6': 'Non-malignant',
                      'Unnamed: 7': 'Quartan','Unnamed: 8':'Double Tertian',
                      'Unnamed: 9' : 'Plasmodium', 'Unnamed: 10': 'local'
                      ,'Unnamed: 11': 'Introduced' , 'Unnamed: 12': 'Alien'
                      , 'Unnamed: 13' : 'Non-catagorized', 'Unnamed: 14' : 'regressive' })
# ---------------------------------------

index = ('Dammam', 'Al-ahssa', 'Al-jowf', 
         'Northern-Borders', 'Qurayat', 
         'hafar-albatin', 'Qaseem', 'Riyadh',
         'Bishaa', 'Najraan', 'Tabook', 'Hail',
         'Madena', 'Taif', 'Mecca', 'Jeddah', 
         'Allaith', 'Alqunfthah', 'Bahaa', 'Jazaan',
         'Aseer', 'Total')

df22diff = df22['No.Tested'] - df22['Pos Casses']
df22.insert(loc = 2,
          column = 'Neg Casses',
          value = df22diff)

df22 = df22.set_index(pd.Index(index))

df22.to_csv("cleaned/2022.csv")

# %% [markdown]
# ## Total

# %%
dfttl = dfttl.drop(['Unnamed: 0'], axis=1)
dfttl= dfttl.rename(columns= {'Unnamed: 2':'No.Tested', 'Unnamed: 3' : 'Pos Casses',
                      'Unnamed: 4': 'malignant' , 'Unnamed: 5': 'Non-malignant',
                      'Unnamed: 6': 'Quartan','Unnamed: 7':'Plasmodium',
                      'Unnamed: 8' : 'Double Tertian', 'Unnamed: 9': 'local'
                      ,'Unnamed: 10': 'Introduced' , 'Unnamed: 11': 'Alien'
                      , 'Unnamed: 12' : 'Non-catagorized', 'Unnamed: 13' : 'regressive' })

dfttldiff = dfttl['No.Tested'] - dfttl['Pos Casses']
dfttl.insert(loc = 2,
          column = 'Neg Casses',
          value = dfttldiff)

dfttlper = dfttl['Pos Casses'] / dfttl['No.Tested'] *100
dfttl.insert(loc = 3, 
            column = '% of Pos',
            value = dfttlper)

dfttl.to_csv("cleaned/ttl.csv")

# %% [markdown]
# # Creating a Dataframe for each province

# %% [markdown]
# ## Dammam

# %%
dammamdf = pd.DataFrame(columns=['No.Tested', 'Pos Casses',
                                 'Neg Casses', '% of Pos',
                                 'malignant', 'Non-malignant',
                                 'Quartan', 'Double Tertian',
                                 'Plasmodium', 'local',
                                 'Introduced', 'Alien',
                                 'Non-catagorized', 'regressive'])

dammamdf.loc['2018'] = df18.loc['Dammam']
dammamdf.loc['2019'] = df19.loc['Dammam']
dammamdf.loc['2020'] = df20.loc['Dammam']
dammamdf.loc['2021'] = df21.loc['Dammam']
dammamdf.loc['2022'] = df22.loc['Dammam']

dammamdf = dammamdf.fillna(0)

dammamdf.to_csv("province/dammam.csv")

# %% [markdown]
# ## Al-ahssa

# %%
alahssadf = pd.DataFrame(columns=['No.Tested', 'Pos Casses',
                                 'Neg Casses', '% of Pos',
                                 'malignant', 'Non-malignant',
                                 'Quartan', 'Double Tertian',
                                 'Plasmodium', 'local',
                                 'Introduced', 'Alien',
                                 'Non-catagorized', 'regressive'])

alahssadf.loc['2018'] = df18.loc['Al-ahssa']
alahssadf.loc['2019'] = df19.loc['Al-ahssa']
alahssadf.loc['2020'] = df20.loc['Al-ahssa']
alahssadf.loc['2021'] = df21.loc['Al-ahssa']
alahssadf.loc['2022'] = df22.loc['Al-ahssa']

alahssadf = alahssadf.fillna(0)

alahssadf.to_csv("province/alahssa.csv")

# %% [markdown]
# ## Al-jowf

# %%
aljowfdf = pd.DataFrame(columns=['No.Tested', 'Pos Casses',
                                 'Neg Casses', '% of Pos',
                                 'malignant', 'Non-malignant',
                                 'Quartan', 'Double Tertian',
                                 'Plasmodium', 'local',
                                 'Introduced', 'Alien',
                                 'Non-catagorized', 'regressive'])

aljowfdf.loc['2018'] = df18.loc['Al-jowf']
aljowfdf.loc['2019'] = df19.loc['Al-jowf']
aljowfdf.loc['2020'] = df20.loc['Al-jowf']
aljowfdf.loc['2021'] = df21.loc['Al-jowf']
aljowfdf.loc['2022'] = df22.loc['Al-jowf']

aljowfdf = aljowfdf.fillna(0)

aljowfdf.to_csv("province/aljowf.csv")

# %% [markdown]
# ## Northern-Borders

# %%
northernbordersdf = pd.DataFrame(columns=['No.Tested', 'Pos Casses',
                                 'Neg Casses', '% of Pos',
                                 'malignant', 'Non-malignant',
                                 'Quartan', 'Double Tertian',
                                 'Plasmodium', 'local',
                                 'Introduced', 'Alien',
                                 'Non-catagorized', 'regressive'])

northernbordersdf.loc['2018'] = df18.loc['Northern-Borders']
northernbordersdf.loc['2019'] = df19.loc['Northern-Borders']
northernbordersdf.loc['2020'] = df20.loc['Northern-Borders']
northernbordersdf.loc['2021'] = df21.loc['Northern-Borders']
northernbordersdf.loc['2022'] = df22.loc['Northern-Borders']

northernbordersdf = northernbordersdf.fillna(0)

northernbordersdf.to_csv("province/aljowf.csv")

# %% [markdown]
# ## Qurrayat

# %%
qurayatdf = pd.DataFrame(columns=['No.Tested', 'Pos Casses',
                                 'Neg Casses', '% of Pos',
                                 'malignant', 'Non-malignant',
                                 'Quartan', 'Double Tertian',
                                 'Plasmodium', 'local',
                                 'Introduced', 'Alien',
                                 'Non-catagorized', 'regressive'])

qurayatdf.loc['2018'] = df18.loc['Qurayat']
qurayatdf.loc['2019'] = df19.loc['Qurayat']
qurayatdf.loc['2020'] = df20.loc['Qurayat']
qurayatdf.loc['2021'] = df21.loc['Qurayat']
qurayatdf.loc['2022'] = df22.loc['Qurayat']

qurayatdf = qurayatdf.fillna(0)

qurayatdf.to_csv("province/aljowf.csv")

# %% [markdown]
# # Visualizing each Province

# %% [markdown]
# ## Dammam

# %%
fig, axes = plt.subplots(figsize=(10,12), nrows=2, ncols=2)

dammamdf["No.Tested"].plot(ax=axes[0,0], kind='bar', color = 'orange'
                            , xlabel = 'Year', title = 'No.Tested')
dammamdf["Pos Casses"].plot(ax=axes[0,1], kind='bar', color = 'Green'
                            , xlabel = 'Year', title = 'Positive Casses')
dammamdf["Neg Casses"].plot(ax=axes[1,0], kind='bar', color = 'Red'
                            , xlabel = 'Year', title = 'Negative Casses')
dammamdf["% of Pos"].plot(ax=axes[1,1], color = 'Pink'
                            , xlabel = 'Year', title = '% of Positive casses', grid = True)
fig.savefig('province_graph/dammamsub.png')

dammamdf[['malignant','Non-malignant','Quartan','Double Tertian','Plasmodium']].plot(kind = 'bar', stacked = True, xlabel = 'Years' , 
                                                                                    title = 'Types', ylabel = 'Number of Casses')
plt.savefig('province_graph/dammamcata.png')

dammamdf[['local','Alien','Non-catagorized']].plot(kind = 'bar', stacked = True, xlabel = 'Years' , 
                                                                                    title = 'Types of Residency', ylabel = 'Number of Casses')

plt.savefig('province_graph/dammamtypes.png')

labels = ['Malignant', 'Non-Malignant', 'Quartan', 'Double Tertian', 'Plasmodium']
total = [4,3,2,81]
fig = plt.figure(figsize=(12,10), dpi=400)
fig.suptitle('Dammam', fontsize = 16)
# ----------------------------
ax1 = plt.subplot2grid((3,2),(0,0))
plt.pie(dammamdf.transpose()['2018'][4:8], autopct='%1.1f%%', pctdistance=1.15,explode=(0.1, 0.1, 1, 0.1), )
plt.legend(labels, loc = "best", bbox_to_anchor = (1,1))
plt.title('2018')

ax1 = plt.subplot2grid((3,2),(0,1))
plt.pie(dammamdf.transpose()['2019'][4:8], autopct='%1.1f%%', pctdistance=1.15,explode=(0.1, 0.1, 1, 0.1), )
plt.legend(labels, loc = "best", bbox_to_anchor = (1,1))
plt.title('2019')

ax1 = plt.subplot2grid((3,2),(1,0))
plt.pie(dammamdf.transpose()['2020'][4:8], autopct='%1.1f%%', pctdistance=1.15,explode=(0.1, 0.1, 1, 0.1), )
plt.legend(labels, loc = "best", bbox_to_anchor = (1,1))
plt.title('2020')

ax1 = plt.subplot2grid((3,2),(1,1))
plt.pie(dammamdf.transpose()['2021'][4:8], autopct='%1.1f%%', pctdistance=1.15,explode=(0.5, 0.1, 1, 0.1), )
plt.legend(labels, loc = "best", bbox_to_anchor = (1,1))
plt.title('2021')

ax1 = plt.subplot2grid((3,2),(2,0))
plt.pie(dammamdf.transpose()['2022'][4:8], autopct='%1.1f%%', pctdistance=1.15,explode=(0.1, 0.1, 1, 0.1), )
plt.legend(labels, loc = "best", bbox_to_anchor = (1,1))
plt.title('2022')

fig.savefig('province_graph/dammapie.png')

# %% [markdown]
# ## Al-ahssa

# %%
fig, axes = plt.subplots(figsize=(10,12), nrows=2, ncols=2)

fig.suptitle('Al-ahssa Malaria Casses', fontsize=16)
alahssadf["No.Tested"].plot(ax=axes[0,0], kind='bar', color = 'orange'
                            , xlabel = 'Year', title = 'No.Tested')
alahssadf["Pos Casses"].plot(ax=axes[0,1], kind='bar', color = 'Green'
                            , xlabel = 'Year', title = 'Positive Casses')
alahssadf["Neg Casses"].plot(ax=axes[1,0], kind='bar', color = 'Red'
                            , xlabel = 'Year', title = 'Negative Casses')
alahssadf["% of Pos"].plot(ax=axes[1,1], color = 'Pink'
                            , xlabel = 'Year', title = '% of Positive casses', grid = True)
fig.savefig('province_graph/alahssasub.png')

alahssadf[['malignant','Non-malignant','Quartan','Double Tertian','Plasmodium']].plot(kind = 'bar', stacked = True, xlabel = 'Years' , 
                                                                                    title = 'Types', ylabel = 'Number of Casses')
plt.savefig('province_graph/alahssacata.png')

alahssadf[['local','Alien','Non-catagorized']].plot(kind = 'bar', stacked = True, xlabel = 'Years' , 
                                                                                    title = 'Types of Residency', ylabel = 'Number of Casses')
plt.savefig('province_graph/alahssatypes.png')

labels = ['Malignant', 'Non-Malignant', 'Quartan', 'Double Tertian', 'Plasmodium']
total = [4,3,2,81]
fig = plt.figure(figsize=(12,10), dpi=400)
fig.suptitle('alahssa', fontsize = 16)
# ----------------------------
ax1 = plt.subplot2grid((3,2),(0,0))
plt.pie(alahssadf.transpose()['2018'][4:8], autopct='%1.1f%%', pctdistance=1.15,explode=(0.1, 0.1, 1, 0.1), )
plt.legend(labels, loc = "best", bbox_to_anchor = (1,1))
plt.title('2018')

ax1 = plt.subplot2grid((3,2),(0,1))
plt.pie(alahssadf.transpose()['2019'][4:8], autopct='%1.1f%%', pctdistance=1.15,explode=(0.1, 0.1, 1, 0.1), )
plt.legend(labels, loc = "best", bbox_to_anchor = (1,1))
plt.title('2019')

ax1 = plt.subplot2grid((3,2),(1,0))
plt.pie(alahssadf.transpose()['2020'][4:8], autopct='%1.1f%%', pctdistance=1.15,explode=(0.1, 0.1, 1, 0.1), )
plt.legend(labels, loc = "best", bbox_to_anchor = (1,1))
plt.title('2020')

ax1 = plt.subplot2grid((3,2),(1,1))
plt.pie(alahssadf.transpose()['2021'][4:8], autopct='%1.1f%%', pctdistance=1.15,explode=(0.5, 0.1, 1, 0.1), )
plt.legend(labels, loc = "best", bbox_to_anchor = (1,1))
plt.title('2021')

ax1 = plt.subplot2grid((3,2),(2,0))
plt.pie(alahssadf.transpose()['2022'][4:8], autopct='%1.1f%%', pctdistance=1.15,explode=(0.1, 0.1, 1, 0.1), )
plt.legend(labels, loc = "best", bbox_to_anchor = (1,1))
plt.title('2022')

fig.savefig('province_graph/dammapie.png')

# %% [markdown]
# ## Al-jowf

# %%
fig, axes = plt.subplots(figsize=(10,12), nrows=2, ncols=2)

fig.suptitle('Al-ahssa Malaria Casses', fontsize=16)
aljowfdf["No.Tested"].plot(ax=axes[0,0], kind='bar', color = 'orange'
                            , xlabel = 'Year', title = 'No.Tested')
aljowfdf["Pos Casses"].plot(ax=axes[0,1], kind='bar', color = 'Green'
                            , xlabel = 'Year', title = 'Positive Casses')
aljowfdf["Neg Casses"].plot(ax=axes[1,0], kind='bar', color = 'Red'
                            , xlabel = 'Year', title = 'Negative Casses')
aljowfdf["% of Pos"].plot(ax=axes[1,1], color = 'Pink'
                            , xlabel = 'Year', title = '% of Positive casses', grid = True)
fig.savefig('province_graph/aljowfsub.png')

aljowfdf[['malignant','Non-malignant','Quartan','Double Tertian','Plasmodium']].plot(kind = 'bar', stacked = True, xlabel = 'Years' , 
                                                                                    title = 'Types', ylabel = 'Number of Casses')
plt.savefig('province_graph/aljowfcata.png')

aljowfdf[['local','Alien','Non-catagorized']].plot(kind = 'bar', stacked = True, xlabel = 'Years' , 
                                                                                    title = 'Types of Residency', ylabel = 'Number of Casses')
plt.savefig('province_graph/aljowftypes.png')

labels = ['Malignant', 'Non-Malignant', 'Quartan', 'Double Tertian', 'Plasmodium']
total = [4,3,2,81]
fig = plt.figure(figsize=(12,10), dpi=400)
fig.suptitle('aljowf', fontsize = 16)
# ----------------------------
ax1 = plt.subplot2grid((3,2),(0,0))
plt.pie(aljowfdf.transpose()['2018'][4:8], autopct='%1.1f%%', pctdistance=1.15,explode=(0.1, 0.1, 1, 0.1), )
plt.legend(labels, loc = "best", bbox_to_anchor = (1,1))
plt.title('2018')

ax1 = plt.subplot2grid((3,2),(0,1))
plt.pie(aljowfdf.transpose()['2019'][4:8], autopct='%1.1f%%', pctdistance=1.15,explode=(0.1, 0.1, 1, 0.1), )
plt.legend(labels, loc = "best", bbox_to_anchor = (1,1))
plt.title('2019')

ax1 = plt.subplot2grid((3,2),(1,0))
plt.pie(aljowfdf.transpose()['2020'][4:8], autopct='%1.1f%%', pctdistance=1.15,explode=(0.1, 0.1, 1, 0.1), )
plt.legend(labels, loc = "best", bbox_to_anchor = (1,1))
plt.title('2020')

ax1 = plt.subplot2grid((3,2),(1,1))
plt.pie(aljowfdf.transpose()['2021'][4:8], autopct='%1.1f%%', pctdistance=1.15,explode=(0.5, 0.1, 1, 0.1), )
plt.legend(labels, loc = "best", bbox_to_anchor = (1,1))
plt.title('2021')

ax1 = plt.subplot2grid((3,2),(2,0))
plt.pie(aljowfdf.transpose()['2022'][4:8], autopct='%1.1f%%', pctdistance=1.15,explode=(0.1, 0.1, 1, 0.1), )
plt.legend(labels, loc = "best", bbox_to_anchor = (1,1))
plt.title('2022')

fig.savefig('province_graph/dammapie.png')

# %% [markdown]
# ## Qurayat

# %%
fig, axes = plt.subplots(figsize=(10,12), nrows=2, ncols=2)

fig.suptitle('Al-jowf Malaria Casses', fontsize=16)
aljowfdf["No.Tested"].plot(ax=axes[0,0], kind='bar', color = 'orange'
                            , xlabel = 'Year', title = 'No.Tested')
aljowfdf["Pos Casses"].plot(ax=axes[0,1], kind='bar', color = 'Green'
                            , xlabel = 'Year', title = 'Positive Casses')
aljowfdf["Neg Casses"].plot(ax=axes[1,0], kind='bar', color = 'Red'
                            , xlabel = 'Year', title = 'Negative Casses')
aljowfdf["% of Pos"].plot(ax=axes[1,1], color = 'Pink'
                            , xlabel = 'Year', title = '% of Positive casses', grid = True)
fig.savefig('province_graph/aljowfsub.png')

aljowfdf[['malignant','Non-malignant','Quartan','Double Tertian','Plasmodium']].plot(kind = 'bar', stacked = True, xlabel = 'Years' , 
                                                                                    title = 'Types', ylabel = 'Number of Casses')
plt.savefig('province_graph/aljowfcata.png')

aljowfdf[['local','Alien','Non-catagorized']].plot(kind = 'bar', stacked = True, xlabel = 'Years' , 
                                                                                    title = 'Types of Residency', ylabel = 'Number of Casses')
plt.savefig('province_graph/aljowftypes.png')

labels = ['Malignant', 'Non-Malignant', 'Quartan', 'Double Tertian', 'Plasmodium']
total = [4,3,2,81]
fig = plt.figure(figsize=(12,10), dpi=400)
fig.suptitle('aljowf', fontsize = 16)
# ----------------------------
ax1 = plt.subplot2grid((3,2),(0,0))
plt.pie(aljowfdf.transpose()['2018'][4:8], autopct='%1.1f%%', pctdistance=1.15,explode=(0.1, 0.1, 1, 0.1), )
plt.legend(labels, loc = "best", bbox_to_anchor = (1,1))
plt.title('2018')

ax1 = plt.subplot2grid((3,2),(0,1))
plt.pie(aljowfdf.transpose()['2019'][4:8], autopct='%1.1f%%', pctdistance=1.15,explode=(0.1, 0.1, 1, 0.1), )
plt.legend(labels, loc = "best", bbox_to_anchor = (1,1))
plt.title('2019')

ax1 = plt.subplot2grid((3,2),(1,0))
plt.pie(aljowfdf.transpose()['2020'][4:8], autopct='%1.1f%%', pctdistance=1.15,explode=(0.1, 0.1, 1, 0.1), )
plt.legend(labels, loc = "best", bbox_to_anchor = (1,1))
plt.title('2020')

ax1 = plt.subplot2grid((3,2),(1,1))
plt.pie(aljowfdf.transpose()['2021'][4:8], autopct='%1.1f%%', pctdistance=1.15,explode=(0.5, 0.1, 1, 0.1), )
plt.legend(labels, loc = "best", bbox_to_anchor = (1,1))
plt.title('2021')

ax1 = plt.subplot2grid((3,2),(2,0))
plt.pie(aljowfdf.transpose()['2022'][4:8], autopct='%1.1f%%', pctdistance=1.15,explode=(0.1, 0.1, 1, 0.1), )
plt.legend(labels, loc = "best", bbox_to_anchor = (1,1))
plt.title('2022')

fig.savefig('province_graph/qurayatpie.png')
